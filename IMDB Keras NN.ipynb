# %%
from keras.models import Model,Sequential
from keras.layers import Input, Dense,Dropout,Activation, Flatten,Convolution2D,MaxPooling2D
import numpy as np
from keras.utils import np_utils

# %%
from keras.datasets import imdb

# %%
(x_train, y_train),(x_test, y_test) = imdb.load_data()

# %%
x_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
o = [len(i) for i in x_train]
print(max(o))
# Out:
# 2494

# %%
for i in x_train:
    if len(i) != 2500:
        for j in range(0,2500-len(i)):
            i.append(0)

# %%
x_train.shape
# Out:
# (25000,)

# %%
type(x_train[0])
# Out:
# list

# %%
x_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
for i in x_train:
    for j in range(0,len(i)):
        i[j] /= 1000000

# %%
for i in x_train:
    if len(i) != 2500:
        print("FALSE")
        break

# %%
for i in range(0,len(x_train)):
    x_train[i] = np.array(x_train[i])

# %%
y_train = np.asarray(y_train).astype('float32')

# %%
model = Sequential()
model.add(Dense(100,activation="relu",input_shape = (2500,)))
model.add(Dense(50,activation="relu"))
model.add(Dense(1,activation="softmax"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = Sequential()
#       2 model.add(Dense(100,activation="relu",input_shape = (2500,)))
#       3 model.add(Dense(50,activation="relu"))
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(x_train,y_train,batch_size=32,epochs=10,verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.fit(x_train,y_train,batch_size=32,epochs=10,verbose=1)
#
# NameError: name 'model' is not defined

# %%
def vectorize(sequences, dimension=2500):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1
  return results

x_train = vectorize(x_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 7
#       4     results[i, sequence] = 1
#       5   return results
# ----> 7 x_train = vectorize(x_train)
#
# Cell In[7], line 4, in vectorize(sequences, dimension)
#       2 results = np.zeros((len(sequences), dimension))
#       3 for i, sequence in enumerate(sequences):
# ----> 4   results[i, sequence] = 1
#       5 return results
#
# IndexError: index 4468 is out of bounds for axis 1 with size 2500
