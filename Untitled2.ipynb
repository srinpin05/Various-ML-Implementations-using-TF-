# %%
pip install twilio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from twilio.rest import Client

account_sid = 'AC61ee89bad570bf23eaa4960fbb6e5e9a'
auth_token = '05ecb74f0764917e3f067c6afe338f68'
client = Client(account_sid, auth_token)

message = client.messages.create(
  from_='+18449561123',
  body='Hello',
  to='+18327983800'
)

print(message.sid)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...
